# %%
import json
import pandas as pd
pd.options.display.max_rows = 4000

# %%
frontapp_schema_meta = {}
saleor_schema_meta = {}

with open('../data/frontapp-schema.json', 'r') as json_file:
    # this file is gitignored
    frontapp_schema_meta = json.load(json_file)
with open('../data/saleor-schema.json', 'r') as json_file:
    saleor_schema_meta = json.load(json_file)

frontapp_schema_df = pd.DataFrame(frontapp_schema_meta["types"])
saleor_schema_df = pd.DataFrame(saleor_schema_meta["data"]["__schema"]["types"])

# %%
print(frontapp_schema_df.shape)
print(saleor_schema_df.shape)
# Out:
# (124, 5)
# (708, 3)

# %% [markdown]
# ### Frontapp schema metrics

# %%
print("Kinds of types in schema:", frontapp_schema_df.kind.unique())

introspection_df = frontapp_schema_df[frontapp_schema_df.name.str.contains("_")]
print("Introspection types:", introspection_df.shape[0])
# print(introspection_df.head(introspection_df.shape[0]))

enum_df = frontapp_schema_df[(frontapp_schema_df.kind == "ENUM")]
print("Enum types:", enum_df.shape[0])
# print(enum_df.head(enum_df.shape[0]))

union_df = frontapp_schema_df[(frontapp_schema_df.kind == "UNION")]
print("Union types:", union_df.shape[0])
# print(union_df.head(union_df.shape[0]))

interface_df = frontapp_schema_df[(frontapp_schema_df.kind == "INTERFACE")]
print("Interface types:", interface_df.shape[0])
# print(interface_df.head(interface_df.shape[0]))

scalar_df = frontapp_schema_df[(frontapp_schema_df.kind == "SCALAR")]
print("Scalar types:", scalar_df.shape[0])
# print(scalar_df.head(scalar_df.shape[0]))

# object_df = frontapp_schema_df[(frontapp_schema_df.kind == "OBJECT") & 
#                                (frontapp_schema_df.name != "Query") & 
#                                (frontapp_schema_df.name != "Mutation") &
#                                (frontapp_schema_df.name.str.contains("_") == 0)]

# We don't include tuples for introspection types in the set of schema tuples
object_df = frontapp_schema_df[(frontapp_schema_df.kind == "OBJECT") &
                               (frontapp_schema_df.name.str.contains("_") == 0)]
print("Object types:", object_df.shape[0])
# print(object_df.head(object_df.shape[0]))

input_df = frontapp_schema_df[(frontapp_schema_df.kind == "INPUT_OBJECT")]
print("Input types:", input_df.shape[0])
# print(input_df.head(input_df.shape[0]))

query_df = frontapp_schema_df[frontapp_schema_df.name == "Query"]["fields"].tolist()
query_df = pd.DataFrame(query_df).transpose()
print("Query entrypoints (may include introspections):", query_df.shape[0])

mutation_df = frontapp_schema_df[frontapp_schema_df.name == "Mutation"]["fields"].tolist()
mutation_df = pd.DataFrame(mutation_df).transpose()
print("Mutation entrypoints (may include introspections):", mutation_df.shape[0])
# Out:
# Kinds of types in schema: ['OBJECT' 'SCALAR' 'ENUM' 'INTERFACE']
# Introspection types: 8
# Enum types: 17
# Union types: 0
# Interface types: 4
# Scalar types: 5
# Object types: 92
# Input types: 0
# Query entrypoints (may include introspections): 23
# Mutation entrypoints (may include introspections): 0

# %%
query_df[0]
# Out:
# 0     {'name': 'company', 'type': {'name': 'Company'...
# 1     {'name': 'companies', 'type': {'name': None, '...
# 2     {'name': 'article', 'type': {'name': 'BaseArti...
# 3     {'name': 'articles', 'type': {'name': 'Article...
# 4     {'name': 'videos', 'type': {'name': 'Videos', ...
# 5     {'name': 'video', 'type': {'name': 'Video', 'k...
# 6     {'name': 'externalArticle', 'type': {'name': '...
# 7     {'name': 'upcomingEvents', 'type': {'name': No...
# 8     {'name': 'recentEvents', 'type': {'name': None...
# 9     {'name': 'event', 'type': {'name': 'Event', 'k...
# 10    {'name': 'portfolio', 'type': {'name': 'Portfo...
# 11    {'name': 'me', 'type': {'name': 'UserInfo', 'k...
# 12    {'name': 'search', 'type': {'name': 'SearchRes...
# 13    {'name': 'searchResults', 'type': {'name': Non...
# 14    {'name': 'ratingStatistics', 'type': {'name': ...
# 15    {'name': 'equityTransactions', 'type': {'name'...
# 16    {'name': 'equityTransaction', 'type': {'name':...
# 17    {'name': 'topCommunityPosts', 'type': {'name':...
# 18    {'name': 'themes', 'type': {'name': None, 'kin...
# 19    {'name': 'nowTeasers', 'type': {'name': None, ...
# 20    {'name': 'indexChart', 'type': {'name': None, ...
# 21    {'name': 'person', 'type': {'name': 'Person', ...
# 22    {'name': 'persons', 'type': {'name': None, 'ki...
# Name: 0, dtype: object

# %% [markdown]
# ### Saleor schema metrics

# %%
print("Kinds of types in schema:", saleor_schema_df.kind.unique())

introspection_df = saleor_schema_df[saleor_schema_df.name.str.contains("_")]
print("Introspection types:", introspection_df.shape[0])
# print(introspection_df.head(introspection_df.shape[0]))

enum_df = saleor_schema_df[(saleor_schema_df.kind == "ENUM")]
print("Enum types:", enum_df.shape[0])
# print(enum_df.head(enum_df.shape[0]))

union_df = saleor_schema_df[(saleor_schema_df.kind == "UNION")]
print("Union types:", union_df.shape[0])
# print(union_df.head(union_df.shape[0]))

interface_df = saleor_schema_df[(saleor_schema_df.kind == "INTERFACE")]
print("Interface types:", interface_df.shape[0])
# print(interface_df.head(interface_df.shape[0]))

scalar_df = saleor_schema_df[(saleor_schema_df.kind == "SCALAR")]
print("Scalar types:", scalar_df.shape[0])
# print(scalar_df.head(scalar_df.shape[0]))

# object_df = saleor_schema_df[(saleor_schema_df.kind == "OBJECT") & 
#                              (saleor_schema_df.name != "Query") & 
#                              (saleor_schema_df.name != "Mutation") &
#                              (saleor_schema_df.name.str.contains("_") == 0)]

# We don't include tuples for introspection types in the set of schema tuples
object_df = saleor_schema_df[(saleor_schema_df.kind == "OBJECT") &
                             (saleor_schema_df.name.str.contains("_") == 0)]
print("Object types:", object_df.shape[0])
# print(object_df.head(object_df.shape[0]))

input_df = saleor_schema_df[(saleor_schema_df.kind == "INPUT_OBJECT")]
print("Input types:", input_df.shape[0])
# print(input_df.head(input_df.shape[0]))

query_df = saleor_schema_df[saleor_schema_df.name == "Query"]["fields"].tolist()
query_df = pd.DataFrame(query_df).transpose()
print("Query entrypoints (may include introspections):", query_df.shape[0])

mutation_df = saleor_schema_df[saleor_schema_df.name == "Mutation"]["fields"].tolist()
mutation_df = pd.DataFrame(mutation_df).transpose()
print("Mutation entrypoints (may include introspections):", mutation_df.shape[0])
# Out:
# Kinds of types in schema: ['OBJECT' 'INTERFACE' 'SCALAR' 'ENUM' 'INPUT_OBJECT' 'UNION']
# Introspection types: 11
# Enum types: 86
# Union types: 2
# Interface types: 3
# Scalar types: 14
# Object types: 460
# Input types: 136
# Query entrypoints (may include introspections): 69
# Mutation entrypoints (may include introspections): 222

# %%
query_df[0]
# Out:
# 0     {'name': 'webhook', 'type': {'name': 'Webhook'...
# 1     {'name': 'webhookEvents', 'type': {'name': Non...
# 2     {'name': 'webhookSamplePayload', 'type': {'nam...
# 3     {'name': 'warehouse', 'type': {'name': 'Wareho...
# 4     {'name': 'warehouses', 'type': {'name': 'Wareh...
# 5     {'name': 'translations', 'type': {'name': 'Tra...
# 6     {'name': 'translation', 'type': {'name': 'Tran...
# 7     {'name': 'stock', 'type': {'name': 'Stock', 'k...
# 8     {'name': 'stocks', 'type': {'name': 'StockCoun...
# 9     {'name': 'shop', 'type': {'name': None, 'kind'...
# 10    {'name': 'shippingZone', 'type': {'name': 'Shi...
# 11    {'name': 'shippingZones', 'type': {'name': 'Sh...
# 12    {'name': 'digitalContent', 'type': {'name': 'D...
# 13    {'name': 'digitalContents', 'type': {'name': '...
# 14    {'name': 'attributes', 'type': {'name': 'Attri...
# 15    {'name': 'attribute', 'type': {'name': 'Attrib...
# 16    {'name': 'categories', 'type': {'name': 'Categ...
# 17    {'name': 'category', 'type': {'name': 'Categor...
# 18    {'name': 'collection', 'type': {'name': 'Colle...
# 19    {'name': 'collections', 'type': {'name': 'Coll...
# 20    {'name': 'product', 'type': {'name': 'Product'...
# 21    {'name': 'products', 'type': {'name': 'Product...
# 22    {'name': 'productType', 'type': {'name': 'Prod...
# 23    {'name': 'productTypes', 'type': {'name': 'Pro...
# 24    {'name': 'productVariant', 'type': {'name': 'P...
# 25    {'name': 'productVariants', 'type': {'name': '...
# 26    {'name': 'reportProductSales', 'type': {'name'...
# 27    {'name': 'payment', 'type': {'name': 'Payment'...
# 28    {'name': 'payments', 'type': {'name': 'Payment...
# 29    {'name': 'page', 'type': {'name': 'Page', 'kin...
# 30    {'name': 'pages', 'type': {'name': 'PageCounta...
# 31    {'name': 'homepageEvents', 'type': {'name': 'O...
# 32    {'name': 'order', 'type': {'name': 'Order', 'k...
# 33    {'name': 'orders', 'type': {'name': 'OrderCoun...
# 34    {'name': 'draftOrders', 'type': {'name': 'Orde...
# 35    {'name': 'ordersTotal', 'type': {'name': 'Taxe...
# 36    {'name': 'orderByToken', 'type': {'name': 'Ord...
# 37    {'name': 'menu', 'type': {'name': 'Menu', 'kin...
# 38    {'name': 'menus', 'type': {'name': 'MenuCounta...
# 39    {'name': 'menuItem', 'type': {'name': 'MenuIte...
# 40    {'name': 'menuItems', 'type': {'name': 'MenuIt...
# 41    {'name': 'giftCard', 'type': {'name': 'GiftCar...
# 42    {'name': 'giftCards', 'type': {'name': 'GiftCa...
# 43    {'name': 'plugin', 'type': {'name': 'Plugin', ...
# 44    {'name': 'plugins', 'type': {'name': 'PluginCo...
# 45    {'name': 'sale', 'type': {'name': 'Sale', 'kin...
# 46    {'name': 'sales', 'type': {'name': 'SaleCounta...
# 47    {'name': 'voucher', 'type': {'name': 'Voucher'...
# 48    {'name': 'vouchers', 'type': {'name': 'Voucher...
# 49    {'name': 'exportFile', 'type': {'name': 'Expor...
# 50    {'name': 'exportFiles', 'type': {'name': 'Expo...
# 51    {'name': 'taxTypes', 'type': {'name': None, 'k...
# 52    {'name': 'checkout', 'type': {'name': 'Checkou...
# 53    {'name': 'checkouts', 'type': {'name': 'Checko...
# 54    {'name': 'checkoutLine', 'type': {'name': 'Che...
# 55    {'name': 'checkoutLines', 'type': {'name': 'Ch...
# 56    {'name': 'appsInstallations', 'type': {'name':...
# 57    {'name': 'apps', 'type': {'name': 'AppCountabl...
# 58    {'name': 'app', 'type': {'name': 'App', 'kind'...
# 59    {'name': 'addressValidationRules', 'type': {'n...
# 60    {'name': 'address', 'type': {'name': 'Address'...
# 61    {'name': 'customers', 'type': {'name': 'UserCo...
# 62    {'name': 'permissionGroups', 'type': {'name': ...
# 63    {'name': 'permissionGroup', 'type': {'name': '...
# 64    {'name': 'me', 'type': {'name': 'User', 'kind'...
# 65    {'name': 'staffUsers', 'type': {'name': 'UserC...
# 66    {'name': 'user', 'type': {'name': 'User', 'kin...
# 67    {'name': '_entities', 'type': {'name': None, '...
# 68    {'name': '_service', 'type': {'name': '_Servic...
# Name: 0, dtype: object

# %%
mutation_df[0]
# Out:
# 0      {'name': 'webhookCreate', 'type': {'name': 'We...
# 1      {'name': 'webhookDelete', 'type': {'name': 'We...
# 2      {'name': 'webhookUpdate', 'type': {'name': 'We...
# 3      {'name': 'createWarehouse', 'type': {'name': '...
# 4      {'name': 'updateWarehouse', 'type': {'name': '...
# 5      {'name': 'deleteWarehouse', 'type': {'name': '...
# 6      {'name': 'assignWarehouseShippingZone', 'type'...
# 7      {'name': 'unassignWarehouseShippingZone', 'typ...
# 8      {'name': 'authorizationKeyAdd', 'type': {'name...
# 9      {'name': 'authorizationKeyDelete', 'type': {'n...
# 10     {'name': 'staffNotificationRecipientCreate', '...
# 11     {'name': 'staffNotificationRecipientUpdate', '...
# 12     {'name': 'staffNotificationRecipientDelete', '...
# 13     {'name': 'homepageCollectionUpdate', 'type': {...
# 14     {'name': 'shopDomainUpdate', 'type': {'name': ...
# 15     {'name': 'shopSettingsUpdate', 'type': {'name'...
# 16     {'name': 'shopFetchTaxRates', 'type': {'name':...
# 17     {'name': 'shopSettingsTranslate', 'type': {'na...
# 18     {'name': 'shopAddressUpdate', 'type': {'name':...
# 19     {'name': 'shippingPriceCreate', 'type': {'name...
# 20     {'name': 'shippingPriceDelete', 'type': {'name...
# 21     {'name': 'shippingPriceBulkDelete', 'type': {'...
# 22     {'name': 'shippingPriceUpdate', 'type': {'name...
# 23     {'name': 'shippingPriceTranslate', 'type': {'n...
# 24     {'name': 'shippingZoneCreate', 'type': {'name'...
# 25     {'name': 'shippingZoneDelete', 'type': {'name'...
# 26     {'name': 'shippingZoneBulkDelete', 'type': {'n...
# 27     {'name': 'shippingZoneUpdate', 'type': {'name'...
# 28     {'name': 'attributeCreate', 'type': {'name': '...
# 29     {'name': 'attributeDelete', 'type': {'name': '...
# 30     {'name': 'attributeBulkDelete', 'type': {'name...
# 31     {'name': 'attributeAssign', 'type': {'name': '...
# 32     {'name': 'attributeUnassign', 'type': {'name':...
# 33     {'name': 'attributeUpdate', 'type': {'name': '...
# 34     {'name': 'attributeTranslate', 'type': {'name'...
# 35     {'name': 'attributeValueCreate', 'type': {'nam...
# 36     {'name': 'attributeValueDelete', 'type': {'nam...
# 37     {'name': 'attributeValueBulkDelete', 'type': {...
# 38     {'name': 'attributeValueUpdate', 'type': {'nam...
# 39     {'name': 'attributeValueTranslate', 'type': {'...
# 40     {'name': 'attributeReorderValues', 'type': {'n...
# 41     {'name': 'categoryCreate', 'type': {'name': 'C...
# 42     {'name': 'categoryDelete', 'type': {'name': 'C...
# 43     {'name': 'categoryBulkDelete', 'type': {'name'...
# 44     {'name': 'categoryUpdate', 'type': {'name': 'C...
# 45     {'name': 'categoryTranslate', 'type': {'name':...
# 46     {'name': 'collectionAddProducts', 'type': {'na...
# 47     {'name': 'collectionCreate', 'type': {'name': ...
# 48     {'name': 'collectionDelete', 'type': {'name': ...
# 49     {'name': 'collectionReorderProducts', 'type': ...
# 50     {'name': 'collectionBulkDelete', 'type': {'nam...
# 51     {'name': 'collectionBulkPublish', 'type': {'na...
# 52     {'name': 'collectionRemoveProducts', 'type': {...
# 53     {'name': 'collectionUpdate', 'type': {'name': ...
# 54     {'name': 'collectionTranslate', 'type': {'name...
# 55     {'name': 'productCreate', 'type': {'name': 'Pr...
# 56     {'name': 'productDelete', 'type': {'name': 'Pr...
# 57     {'name': 'productBulkDelete', 'type': {'name':...
# 58     {'name': 'productBulkPublish', 'type': {'name'...
# 59     {'name': 'productUpdate', 'type': {'name': 'Pr...
# 60     {'name': 'productTranslate', 'type': {'name': ...
# 61     {'name': 'productSetAvailabilityForPurchase', ...
# 62     {'name': 'productImageCreate', 'type': {'name'...
# 63     {'name': 'productVariantReorder', 'type': {'na...
# 64     {'name': 'productImageDelete', 'type': {'name'...
# 65     {'name': 'productImageBulkDelete', 'type': {'n...
# 66     {'name': 'productImageReorder', 'type': {'name...
# 67     {'name': 'productImageUpdate', 'type': {'name'...
# 68     {'name': 'productTypeCreate', 'type': {'name':...
# 69     {'name': 'productTypeDelete', 'type': {'name':...
# 70     {'name': 'productTypeBulkDelete', 'type': {'na...
# 71     {'name': 'productTypeUpdate', 'type': {'name':...
# 72     {'name': 'productTypeReorderAttributes', 'type...
# 73     {'name': 'digitalContentCreate', 'type': {'nam...
# 74     {'name': 'digitalContentDelete', 'type': {'nam...
# 75     {'name': 'digitalContentUpdate', 'type': {'nam...
# 76     {'name': 'digitalContentUrlCreate', 'type': {'...
# 77     {'name': 'productVariantCreate', 'type': {'nam...
# 78     {'name': 'productVariantDelete', 'type': {'nam...
# 79     {'name': 'productVariantBulkCreate', 'type': {...
# 80     {'name': 'productVariantBulkDelete', 'type': {...
# 81     {'name': 'productVariantStocksCreate', 'type':...
# 82     {'name': 'productVariantStocksDelete', 'type':...
# 83     {'name': 'productVariantStocksUpdate', 'type':...
# 84     {'name': 'productVariantUpdate', 'type': {'nam...
# 85     {'name': 'productVariantSetDefault', 'type': {...
# 86     {'name': 'productVariantTranslate', 'type': {'...
# 87     {'name': 'variantImageAssign', 'type': {'name'...
# 88     {'name': 'variantImageUnassign', 'type': {'nam...
# 89     {'name': 'paymentCapture', 'type': {'name': 'P...
# 90     {'name': 'paymentRefund', 'type': {'name': 'Pa...
# 91     {'name': 'paymentVoid', 'type': {'name': 'Paym...
# 92     {'name': 'pageCreate', 'type': {'name': 'PageC...
# 93     {'name': 'pageDelete', 'type': {'name': 'PageD...
# 94     {'name': 'pageBulkDelete', 'type': {'name': 'P...
# 95     {'name': 'pageBulkPublish', 'type': {'name': '...
# 96     {'name': 'pageUpdate', 'type': {'name': 'PageU...
# 97     {'name': 'pageTranslate', 'type': {'name': 'Pa...
# 98     {'name': 'draftOrderComplete', 'type': {'name'...
# 99     {'name': 'draftOrderCreate', 'type': {'name': ...
# 100    {'name': 'draftOrderDelete', 'type': {'name': ...
# 101    {'name': 'draftOrderBulkDelete', 'type': {'nam...
# 102    {'name': 'draftOrderLinesBulkDelete', 'type': ...
# 103    {'name': 'draftOrderLinesCreate', 'type': {'na...
# 104    {'name': 'draftOrderLineDelete', 'type': {'nam...
# 105    {'name': 'draftOrderLineUpdate', 'type': {'nam...
# 106    {'name': 'draftOrderUpdate', 'type': {'name': ...
# 107    {'name': 'orderAddNote', 'type': {'name': 'Ord...
# 108    {'name': 'orderCancel', 'type': {'name': 'Orde...
# 109    {'name': 'orderCapture', 'type': {'name': 'Ord...
# 110    {'name': 'orderFulfill', 'type': {'name': 'Ord...
# 111    {'name': 'orderFulfillmentCancel', 'type': {'n...
# 112    {'name': 'orderFulfillmentUpdateTracking', 'ty...
# 113    {'name': 'orderMarkAsPaid', 'type': {'name': '...
# 114    {'name': 'orderRefund', 'type': {'name': 'Orde...
# 115    {'name': 'orderUpdate', 'type': {'name': 'Orde...
# 116    {'name': 'orderUpdateShipping', 'type': {'name...
# 117    {'name': 'orderVoid', 'type': {'name': 'OrderV...
# 118    {'name': 'orderBulkCancel', 'type': {'name': '...
# 119    {'name': 'deleteMetadata', 'type': {'name': 'D...
# 120    {'name': 'deletePrivateMetadata', 'type': {'na...
# 121    {'name': 'updateMetadata', 'type': {'name': 'U...
# 122    {'name': 'updatePrivateMetadata', 'type': {'na...
# 123    {'name': 'assignNavigation', 'type': {'name': ...
# 124    {'name': 'menuCreate', 'type': {'name': 'MenuC...
# 125    {'name': 'menuDelete', 'type': {'name': 'MenuD...
# 126    {'name': 'menuBulkDelete', 'type': {'name': 'M...
# 127    {'name': 'menuUpdate', 'type': {'name': 'MenuU...
# 128    {'name': 'menuItemCreate', 'type': {'name': 'M...
# 129    {'name': 'menuItemDelete', 'type': {'name': 'M...
# 130    {'name': 'menuItemBulkDelete', 'type': {'name'...
# 131    {'name': 'menuItemUpdate', 'type': {'name': 'M...
# 132    {'name': 'menuItemTranslate', 'type': {'name':...
# 133    {'name': 'menuItemMove', 'type': {'name': 'Men...
# 134    {'name': 'invoiceRequest', 'type': {'name': 'I...
# 135    {'name': 'invoiceRequestDelete', 'type': {'nam...
# 136    {'name': 'invoiceCreate', 'type': {'name': 'In...
# 137    {'name': 'invoiceDelete', 'type': {'name': 'In...
# 138    {'name': 'invoiceUpdate', 'type': {'name': 'In...
# 139    {'name': 'invoiceSendEmail', 'type': {'name': ...
# 140    {'name': 'giftCardActivate', 'type': {'name': ...
# 141    {'name': 'giftCardCreate', 'type': {'name': 'G...
# 142    {'name': 'giftCardDeactivate', 'type': {'name'...
# 143    {'name': 'giftCardUpdate', 'type': {'name': 'G...
# 144    {'name': 'pluginUpdate', 'type': {'name': 'Plu...
# 145    {'name': 'saleCreate', 'type': {'name': 'SaleC...
# 146    {'name': 'saleDelete', 'type': {'name': 'SaleD...
# 147    {'name': 'saleBulkDelete', 'type': {'name': 'S...
# 148    {'name': 'saleUpdate', 'type': {'name': 'SaleU...
# 149    {'name': 'saleCataloguesAdd', 'type': {'name':...
# 150    {'name': 'saleCataloguesRemove', 'type': {'nam...
# 151    {'name': 'saleTranslate', 'type': {'name': 'Sa...
# 152    {'name': 'voucherCreate', 'type': {'name': 'Vo...
# 153    {'name': 'voucherDelete', 'type': {'name': 'Vo...
# 154    {'name': 'voucherBulkDelete', 'type': {'name':...
# 155    {'name': 'voucherUpdate', 'type': {'name': 'Vo...
# 156    {'name': 'voucherCataloguesAdd', 'type': {'nam...
# 157    {'name': 'voucherCataloguesRemove', 'type': {'...
# 158    {'name': 'voucherTranslate', 'type': {'name': ...
# 159    {'name': 'exportProducts', 'type': {'name': 'E...
# 160    {'name': 'checkoutAddPromoCode', 'type': {'nam...
# 161    {'name': 'checkoutBillingAddressUpdate', 'type...
# 162    {'name': 'checkoutComplete', 'type': {'name': ...
# 163    {'name': 'checkoutCreate', 'type': {'name': 'C...
# 164    {'name': 'checkoutCustomerAttach', 'type': {'n...
# 165    {'name': 'checkoutCustomerDetach', 'type': {'n...
# 166    {'name': 'checkoutEmailUpdate', 'type': {'name...
# 167    {'name': 'checkoutLineDelete', 'type': {'name'...
# 168    {'name': 'checkoutLinesAdd', 'type': {'name': ...
# 169    {'name': 'checkoutLinesUpdate', 'type': {'name...
# 170    {'name': 'checkoutRemovePromoCode', 'type': {'...
# 171    {'name': 'checkoutPaymentCreate', 'type': {'na...
# 172    {'name': 'checkoutShippingAddressUpdate', 'typ...
# 173    {'name': 'checkoutShippingMethodUpdate', 'type...
# 174    {'name': 'appCreate', 'type': {'name': 'AppCre...
# 175    {'name': 'appUpdate', 'type': {'name': 'AppUpd...
# 176    {'name': 'appDelete', 'type': {'name': 'AppDel...
# 177    {'name': 'appTokenCreate', 'type': {'name': 'A...
# 178    {'name': 'appTokenDelete', 'type': {'name': 'A...
# 179    {'name': 'appTokenVerify', 'type': {'name': 'A...
# 180    {'name': 'appInstall', 'type': {'name': 'AppIn...
# 181    {'name': 'appRetryInstall', 'type': {'name': '...
# 182    {'name': 'appDeleteFailedInstallation', 'type'...
# 183    {'name': 'appFetchManifest', 'type': {'name': ...
# 184    {'name': 'appActivate', 'type': {'name': 'AppA...
# 185    {'name': 'appDeactivate', 'type': {'name': 'Ap...
# 186    {'name': 'tokenCreate', 'type': {'name': 'Crea...
# 187    {'name': 'tokenRefresh', 'type': {'name': 'Ref...
# 188    {'name': 'tokenVerify', 'type': {'name': 'Veri...
# 189    {'name': 'tokensDeactivateAll', 'type': {'name...
# 190    {'name': 'requestPasswordReset', 'type': {'nam...
# 191    {'name': 'confirmAccount', 'type': {'name': 'C...
# 192    {'name': 'setPassword', 'type': {'name': 'SetP...
# 193    {'name': 'passwordChange', 'type': {'name': 'P...
# 194    {'name': 'requestEmailChange', 'type': {'name'...
# 195    {'name': 'confirmEmailChange', 'type': {'name'...
# 196    {'name': 'accountAddressCreate', 'type': {'nam...
# 197    {'name': 'accountAddressUpdate', 'type': {'nam...
# 198    {'name': 'accountAddressDelete', 'type': {'nam...
# 199    {'name': 'accountSetDefaultAddress', 'type': {...
# 200    {'name': 'accountRegister', 'type': {'name': '...
# 201    {'name': 'accountUpdate', 'type': {'name': 'Ac...
# 202    {'name': 'accountRequestDeletion', 'type': {'n...
# 203    {'name': 'accountDelete', 'type': {'name': 'Ac...
# 204    {'name': 'addressCreate', 'type': {'name': 'Ad...
# 205    {'name': 'addressUpdate', 'type': {'name': 'Ad...
# 206    {'name': 'addressDelete', 'type': {'name': 'Ad...
# 207    {'name': 'addressSetDefault', 'type': {'name':...
# 208    {'name': 'customerCreate', 'type': {'name': 'C...
# 209    {'name': 'customerUpdate', 'type': {'name': 'C...
# 210    {'name': 'customerDelete', 'type': {'name': 'C...
# 211    {'name': 'customerBulkDelete', 'type': {'name'...
# 212    {'name': 'staffCreate', 'type': {'name': 'Staf...
# 213    {'name': 'staffUpdate', 'type': {'name': 'Staf...
# 214    {'name': 'staffDelete', 'type': {'name': 'Staf...
# 215    {'name': 'staffBulkDelete', 'type': {'name': '...
# 216    {'name': 'userAvatarUpdate', 'type': {'name': ...
# 217    {'name': 'userAvatarDelete', 'type': {'name': ...
# 218    {'name': 'userBulkSetActive', 'type': {'name':...
# 219    {'name': 'permissionGroupCreate', 'type': {'na...
# 220    {'name': 'permissionGroupUpdate', 'type': {'na...
# 221    {'name': 'permissionGroupDelete', 'type': {'na...
# Name: 0, dtype: object
