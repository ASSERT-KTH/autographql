# %%
import matplotlib.pyplot as plt
import pandas as pd
from matplotlib_venn import venn2, venn2_circles, venn3, venn3_circles
import numpy as np
pd.options.display.max_rows = 4000

# %% [markdown]
# ### Data

# %%
test_coverage = pd.read_csv('../data/saleorSchemaCoverageDictionaryOriginalTestsWithMutations.csv')
prod_coverage = pd.read_csv('../data/saleorSchemaCoverageDictionary.csv')

# %%
print("Number of schema tuples in test and production:", test_coverage.shape[0]
      if (test_coverage.shape[0] == prod_coverage.shape[0]) 
      else "Unequal number of tuples")
# Out:
# Number of schema tuples in test and production: 1884

# %%
test_coverage.head(5)
# Out:
#                  schemaTuple  visited  timesVisited
# 0               querywebhook     True             4
# 1         querywebhookevents     True             1
# 2  querywebhooksamplepayload     True            12
# 3             querywarehouse     True             4
# 4            querywarehouses     True            12

# %%
prod_coverage.head(5)
# Out:
#                  schemaTuple  visited  timesVisited  \
# 0               querywebhook     True             2
# 1         querywebhookevents    False             0
# 2  querywebhooksamplepayload    False             0
# 3             querywarehouse     True             4
# 4            querywarehouses     True             6
#
#                                      id
# 0  60266ab2-c801-5b24-8323-04c77978eaaf
# 1                                   NaN
# 2                                   NaN
# 3  b745eb61-8ebb-5dfe-86cd-c5df52821d23
# 4  8066442d-d5c3-54fe-bea1-3caaab6410ec

# %% [markdown]
# ### Analysis

# %%
print("Are test and production coverage the same:", test_coverage.equals(prod_coverage))
# Out:
# Are test and production coverage the same: False

# %%
covered_in_test = test_coverage[test_coverage.visited == True].shape[0]
covered_in_prod = prod_coverage[prod_coverage.visited == True].shape[0]

print("=== Original test suite ===")
print("Number of tuples covered by the test suite:", covered_in_test)
print("Percentage of schema tuples covered by the test suite:", (covered_in_test/test_coverage.shape[0]) * 100)

print("=== Generated test suite ===")
print("Number of tuples covered in production:", covered_in_prod)
print("Percentage of schema tuples covered in production:", (covered_in_prod/prod_coverage.shape[0]) * 100)
# Out:
# === Original test suite ===
# Number of tuples covered by the test suite: 1429
# Percentage of schema tuples covered by the test suite: 75.84925690021231
# === Generated test suite ===
# Number of tuples covered in production: 506
# Percentage of schema tuples covered in production: 26.857749469214436

# %%
only_covered_in_test = test_coverage[(prod_coverage.visited == False) & 
                                     (test_coverage.visited == True)]

print("Number of tuples covered in test but not in production:", only_covered_in_test.shape[0])
# Out:
# Number of tuples covered in test but not in production: 946

# %%
covered_by_both = prod_coverage[(prod_coverage.visited == True) & (test_coverage.visited == True)]
print("Tuples covered by both test and production queries:", covered_by_both.shape[0])
# Out:
# Tuples covered by both test and production queries: 483

# %%
only_covered_in_prod = prod_coverage[(prod_coverage.visited == True) & 
                                     (test_coverage.visited == False)]

print("Number of tuples covered in production but not by original tests:", only_covered_in_prod.shape[0])
# Out:
# Number of tuples covered in production but not by original tests: 23

# %%
only_covered_in_prod
# Out:
#                                  schemaTuple  visited  timesVisited  \
# 51                             querytaxtypes     True             2
# 70                          webhooktargeturl     True             2
# 72                          webhooksecretkey     True             2
# 75                                webhookapp     True             3
# 119                               appversion     True             1
# 140  shippingzonecountableconnectionpageinfo     True             1
# 279                       attributeinputtype     True             5
# 374                    productimagesortorder     True             2
# 468                  pagetranslationseotitle     True             2
# 469            pagetranslationseodescription     True             2
# 470                        pagetranslationid     True             2
# 473               pagetranslationcontentjson     True             2
# 475                             pageseotitle     True             5
# 476                       pageseodescription     True             5
# 496                        saletranslationid     True             1
# 518                     vouchertranslationid     True             2
# 554                            menuitemlevel     True             2
# 748              orderlineisshippingrequired     True            10
# 750               orderlinequantityfulfilled     True            10
# 769                         invoicecreatedat     True             4
# 861          pagecountableconnectionpageinfo     True             9
# 891        plugincountableconnectionpageinfo     True             6
# 945         appcountableconnectiontotalcount     True             2
#
#                                        id
# 51   2367594c-e4f7-5fb3-9d1d-780a31269703
# 70   60266ab2-c801-5b24-8323-04c77978eaaf
# 72   60266ab2-c801-5b24-8323-04c77978eaaf
# 75   60266ab2-c801-5b24-8323-04c77978eaaf
# 119  15d37756-9074-5ae7-8ae0-d002b9b3c916
# 140  8e3d7973-6525-520c-9788-e69dca22add3
# 279  2367594c-e4f7-5fb3-9d1d-780a31269703
# 374  2367594c-e4f7-5fb3-9d1d-780a31269703
# 468  67d4f373-2df9-5050-9cc6-8475ff84b884
# 469  67d4f373-2df9-5050-9cc6-8475ff84b884
# 470  67d4f373-2df9-5050-9cc6-8475ff84b884
# 473  67d4f373-2df9-5050-9cc6-8475ff84b884
# 475  1789c80c-e3ac-57d3-8e3e-0dc894bba1a5
# 476  1789c80c-e3ac-57d3-8e3e-0dc894bba1a5
# 496  9e47fdf0-8381-54c5-ad61-17dcef1a425d
# 518  36592a3b-783b-53b9-a5fc-788df4c17841
# 554  e4878bc5-cf6f-5290-8403-b17f788b3985
# 748  38c4706b-23db-5922-9852-b0856018ec3b
# 750  38c4706b-23db-5922-9852-b0856018ec3b
# 769  7cb4bf3d-e621-5c8b-bf51-51d512a56a7d
# 861  cd2250b5-f0c6-5ee0-9496-49c4dfe02e45
# 891  71ef9598-fc8c-54a0-8777-9c87409deeb7
# 945  9ee172d0-207c-546e-a8de-772d127eee76

# %% [markdown]
# ### Merged test and production coverage reports

# %%
merged_df = pd.merge(test_coverage, prod_coverage, on='schemaTuple')
merged_df = merged_df.rename(columns={"visited_x": "visitedTest", 
                                      "visited_y": "visitedProd", 
                                      "timesVisited_x": "timesVisitedTest", 
                                      "timesVisited_y": "timesVisitedProd"})

# %%
merged_df
# Out:
#                                             schemaTuple  visitedTest  \
# 0                                          querywebhook         True
# 1                                    querywebhookevents         True
# 2                             querywebhooksamplepayload         True
# 3                                        querywarehouse         True
# 4                                       querywarehouses         True
# 5                                     querytranslations         True
# 6                                      querytranslation         True
# 7                                            querystock         True
# 8                                           querystocks         True
# 9                                             queryshop         True
# 10                                    queryshippingzone         True
# 11                                   queryshippingzones         True
# 12                                  querydigitalcontent         True
# 13                                 querydigitalcontents         True
# 14                                      queryattributes         True
# 15                                       queryattribute         True
# 16                                      querycategories         True
# 17                                        querycategory         True
# 18                                      querycollection         True
# 19                                     querycollections         True
# 20                                         queryproduct         True
# 21                                        queryproducts         True
# 22                                     queryproducttype         True
# 23                                    queryproducttypes         True
# 24                                  queryproductvariant         True
# 25                                 queryproductvariants         True
# 26                              queryreportproductsales         True
# 27                                         querypayment         True
# 28                                        querypayments         True
# 29                                            querypage         True
# 30                                           querypages         True
# 31                                  queryhomepageevents         True
# 32                                           queryorder         True
# 33                                          queryorders         True
# 34                                     querydraftorders         True
# 35                                     queryorderstotal         True
# 36                                    queryorderbytoken         True
# 37                                            querymenu         True
# 38                                           querymenus         True
# 39                                        querymenuitem         True
# 40                                       querymenuitems         True
# 41                                        querygiftcard         True
# 42                                       querygiftcards         True
# 43                                          queryplugin         True
# 44                                         queryplugins         True
# 45                                            querysale         True
# 46                                           querysales         True
# 47                                         queryvoucher         True
# 48                                        queryvouchers         True
# 49                                      queryexportfile         True
# 50                                     queryexportfiles         True
# 51                                        querytaxtypes        False
# 52                                        querycheckout         True
# 53                                       querycheckouts         True
# 54                                    querycheckoutline         True
# 55                                   querycheckoutlines         True
# 56                               queryappsinstallations         True
# 57                                            queryapps         True
# 58                                             queryapp         True
# 59                          queryaddressvalidationrules         True
# 60                                         queryaddress         True
# 61                                       querycustomers         True
# 62                                querypermissiongroups         True
# 63                                 querypermissiongroup         True
# 64                                              queryme         True
# 65                                      querystaffusers         True
# 66                                            queryuser         True
# 67                                       query_entities         True
# 68                                        query_service        False
# 69                                          webhookname         True
# 70                                     webhooktargeturl        False
# 71                                      webhookisactive         True
# 72                                     webhooksecretkey        False
# 73                                            webhookid         True
# 74                                        webhookevents         True
# 75                                           webhookapp        False
# 76                                               nodeid        False
# 77                                webhookeventeventtype         True
# 78                                     webhookeventname         True
# 79                                     serviceaccountid        False
# 80                                   serviceaccountname        False
# 81                                serviceaccountcreated        False
# 82                               serviceaccountisactive        False
# 83                            serviceaccountpermissions        False
# 84                                 serviceaccounttokens        False
# 85                        serviceaccountprivatemetadata        False
# 86                               serviceaccountmetadata        False
# 87                    objectwithmetadataprivatemetadata         True
# 88                           objectwithmetadatametadata         True
# 89                                      metadataitemkey         True
# 90                                    metadataitemvalue         True
# 91                                   metastorenamespace        False
# 92                                     metastoreclients        False
# 93                                  metaclientstorename        False
# 94                              metaclientstoremetadata        False
# 95                                          metaitemkey        False
# 96                                        metaitemvalue        False
# 97                                       permissioncode         True
# 98                                       permissionname         True
# 99                              serviceaccounttokenname        False
# 100                        serviceaccounttokenauthtoken        False
# 101                               serviceaccounttokenid        False
# 102                                               appid         True
# 103                                             appname         True
# 104                                          appcreated         True
# 105                                         appisactive         True
# 106                                      apppermissions         True
# 107                                           apptokens         True
# 108                                  appprivatemetadata         True
# 109                                         appmetadata         True
# 110                                             apptype         True
# 111                                         appwebhooks         True
# 112                                         appaboutapp         True
# 113                                      appdataprivacy         True
# 114                                   appdataprivacyurl         True
# 115                                      apphomepageurl         True
# 116                                       appsupporturl         True
# 117                                 appconfigurationurl         True
# 118                                           appappurl         True
# 119                                          appversion        False
# 120                                      appaccesstoken         True
# 121                                        apptokenname         True
# 122                                   apptokenauthtoken         True
# 123                                          apptokenid         True
# 124                  webhookcountableconnectionpageinfo        False
# 125                     webhookcountableconnectionedges        False
# 126                webhookcountableconnectiontotalcount        False
# 127                                 pageinfohasnextpage         True
# 128                             pageinfohaspreviouspage         True
# 129                                 pageinfostartcursor         True
# 130                                   pageinfoendcursor         True
# 131                            webhookcountableedgenode        False
# 132                          webhookcountableedgecursor        False
# 133                                         warehouseid         True
# 134                                       warehousename         True
# 135                                       warehouseslug         True
# 136                                warehousecompanyname         True
# 137                              warehouseshippingzones         True
# 138                                    warehouseaddress         True
# 139                                      warehouseemail         True
# 140             shippingzonecountableconnectionpageinfo        False
# 141                shippingzonecountableconnectionedges         True
# 142           shippingzonecountableconnectiontotalcount         True
# 143                       shippingzonecountableedgenode         True
# 144                     shippingzonecountableedgecursor        False
# 145                                      shippingzoneid         True
# 146                                    shippingzonename         True
# 147                                 shippingzonedefault         True
# 148                              shippingzonepricerange         True
# 149                               shippingzonecountries         True
# 150                         shippingzoneshippingmethods         True
# 151                              shippingzonewarehouses         True
# 152                                     moneyrangestart         True
# 153                                      moneyrangestop         True
# 154                                       moneycurrency         True
# 155                                         moneyamount         True
# 156                                  countrydisplaycode         True
# 157                               countrydisplaycountry         True
# 158                                   countrydisplayvat         True
# 159                                      vatcountrycode        False
# 160                                     vatstandardrate         True
# 161                                     vatreducedrates         True
# 162                                     reducedraterate         True
# 163                                 reducedrateratetype         True
# 164                                    shippingmethodid         True
# 165                                  shippingmethodname         True
# 166                                 shippingmethodprice         True
# 167                     shippingmethodminimumorderprice         True
# 168                     shippingmethodmaximumorderprice         True
# 169                    shippingmethodminimumorderweight         True
# 170                    shippingmethodmaximumorderweight         True
# 171                                  shippingmethodtype         True
# 172                           shippingmethodtranslation         True
# 173                                          weightunit         True
# 174                                         weightvalue         True
# 175                         shippingmethodtranslationid        False
# 176                       shippingmethodtranslationname         True
# 177                   shippingmethodtranslationlanguage         True
# 178                                 languagedisplaycode         True
# 179                             languagedisplaylanguage         True
# 180                                           addressid         True
# 181                                    addressfirstname         True
# 182                                     addresslastname         True
# 183                                  addresscompanyname         True
# 184                               addressstreetaddress1         True
# 185                               addressstreetaddress2         True
# 186                                         addresscity         True
# 187                                     addresscityarea         True
# 188                                   addresspostalcode         True
# 189                                      addresscountry         True
# 190                                  addresscountryarea         True
# 191                                        addressphone         True
# 192                     addressisdefaultshippingaddress         True
# 193                      addressisdefaultbillingaddress         True
# 194                warehousecountableconnectionpageinfo         True
# 195                   warehousecountableconnectionedges         True
# 196              warehousecountableconnectiontotalcount         True
# 197                          warehousecountableedgenode         True
# 198                        warehousecountableedgecursor        False
# 199                  translatableitemconnectionpageinfo        False
# 200                     translatableitemconnectionedges         True
# 201                translatableitemconnectiontotalcount        False
# 202                            translatableitemedgenode         True
# 203                          translatableitemedgecursor        False
# 204                        producttranslatablecontentid         True
# 205                  producttranslatablecontentseotitle        False
# 206            producttranslatablecontentseodescription        False
# 207                      producttranslatablecontentname         True
# 208               producttranslatablecontentdescription        False
# 209           producttranslatablecontentdescriptionjson        False
# 210               producttranslatablecontenttranslation         True
# 211                   producttranslatablecontentproduct         True
# 212                                producttranslationid         True
# 213                          producttranslationseotitle         True
# 214                    producttranslationseodescription         True
# 215                              producttranslationname         True
# 216                       producttranslationdescription        False
# 217                   producttranslationdescriptionjson         True
# 218                          producttranslationlanguage         True
# 219                                           productid         True
# 220                                     productseotitle         True
# 221                               productseodescription         True
# 222                                         productname         True
# 223                                  productdescription         True
# 224                              productdescriptionjson         True
# 225                              productpublicationdate         True
# 226                                  productproducttype         True
# 227                                         productslug         True
# 228                                     productcategory         True
# 229                                    productupdatedat         True
# 230                                  productchargetaxes         True
# 231                                       productweight         True
# 232                         productavailableforpurchase         True
# 233                            productvisibleinlistings         True
# 234                               productdefaultvariant         True
# 235                              productprivatemetadata         True
# 236                                     productmetadata         True
# 237                                    productthumbnail         True
# 238                                      productpricing         True
# 239                                  productisavailable         True
# 240                          productminimalvariantprice         True
# 241                                      producttaxtype         True
# 242                                   productattributes         True
# 243                                 productpurchasecost         True
# 244                                       productmargin         True
# 245                                    productimagebyid         True
# 246                                     productvariants         True
# 247                                       productimages         True
# 248                                  productcollections         True
# 249                                  producttranslation         True
# 250                       productisavailableforpurchase         True
# 251                                  productispublished         True
# 252                                       producttypeid         True
# 253                                     producttypename         True
# 254                                     producttypeslug         True
# 255                              producttypehasvariants         True
# 256                       producttypeisshippingrequired         True
# 257                                producttypeisdigital        False
# 258                                   producttypeweight         True
# 259                          producttypeprivatemetadata         True
# 260                                 producttypemetadata         True
# 261                                 producttypeproducts         True
# 262                                  producttypetaxrate         True
# 263                                  producttypetaxtype         True
# 264                        producttypevariantattributes         True
# 265                        producttypeproductattributes         True
# 266                      producttypeavailableattributes         True
# 267                  productcountableconnectionpageinfo         True
# 268                     productcountableconnectionedges         True
# 269                productcountableconnectiontotalcount         True
# 270                            productcountableedgenode         True
# 271                          productcountableedgecursor         True
# 272                                  taxtypedescription         True
# 273                                      taxtypetaxcode         True
# 274                                         attributeid         True
# 275                               attributeproducttypes         True
# 276                        attributeproductvarianttypes        False
# 277                            attributeprivatemetadata         True
# 278                                   attributemetadata         True
# 279                                  attributeinputtype        False
# 280                                       attributename         True
# 281                                       attributeslug         True
# 282                                     attributevalues         True
# 283                              attributevaluerequired         True
# 284                        attributevisibleinstorefront         True
# 285                     attributefilterableinstorefront         True
# 286                      attributefilterableindashboard         True
# 287                            attributeavailableingrid         True
# 288                                attributetranslation         True
# 289                   attributestorefrontsearchposition         True
# 290              producttypecountableconnectionpageinfo         True
# 291                 producttypecountableconnectionedges         True
# 292            producttypecountableconnectiontotalcount         True
# 293                        producttypecountableedgenode         True
# 294                      producttypecountableedgecursor        False
# 295                                    attributevalueid         True
# 296                                  attributevaluename         True
# 297                                  attributevalueslug         True
# 298                           attributevaluetranslation         True
# 299                             attributevalueinputtype         True
# 300                         attributevaluetranslationid         True
# 301                       attributevaluetranslationname         True
# 302                   attributevaluetranslationlanguage         True
# 303                              attributetranslationid         True
# 304                            attributetranslationname         True
# 305                        attributetranslationlanguage         True
# 306                attributecountableconnectionpageinfo         True
# 307                   attributecountableconnectionedges         True
# 308              attributecountableconnectiontotalcount         True
# 309                          attributecountableedgenode         True
# 310                        attributecountableedgecursor        False
# 311                                    categoryseotitle         True
# 312                              categoryseodescription         True
# 313                                          categoryid         True
# 314                                        categoryname         True
# 315                                 categorydescription         True
# 316                             categorydescriptionjson         True
# 317                                        categoryslug         True
# 318                                      categoryparent         True
# 319                                       categorylevel        False
# 320                             categoryprivatemetadata         True
# 321                                    categorymetadata         True
# 322                                   categoryancestors         True
# 323                                    categoryproducts         True
# 324                                    categorychildren         True
# 325                             categorybackgroundimage         True
# 326                                 categorytranslation         True
# 327                 categorycountableconnectionpageinfo         True
# 328                    categorycountableconnectionedges         True
# 329               categorycountableconnectiontotalcount         True
# 330                           categorycountableedgenode         True
# 331                         categorycountableedgecursor        False
# 332                                            imageurl         True
# 333                                            imagealt         True
# 334                         categorytranslationseotitle         True
# 335                   categorytranslationseodescription         True
# 336                               categorytranslationid         True
# 337                             categorytranslationname         True
# 338                      categorytranslationdescription        False
# 339                  categorytranslationdescriptionjson         True
# 340                         categorytranslationlanguage         True
# 341                                    productvariantid         True
# 342                                  productvariantname         True
# 343                                   productvariantsku         True
# 344                               productvariantproduct         True
# 345                        productvarianttrackinventory         True
# 346                                productvariantweight         True
# 347                       productvariantprivatemetadata         True
# 348                              productvariantmetadata         True
# 349                                 productvariantprice         True
# 350                               productvariantpricing         True
# 351                            productvariantattributes         True
# 352                             productvariantcostprice         True
# 353                                productvariantmargin         True
# 354                       productvariantquantityordered         True
# 355                               productvariantrevenue         True
# 356                                productvariantimages         True
# 357                           productvarianttranslation         True
# 358                        productvariantdigitalcontent         True
# 359                                productvariantstocks         True
# 360                     productvariantquantityavailable         True
# 361                            variantpricinginfoonsale         True
# 362                          variantpricinginfodiscount         True
# 363             variantpricinginfodiscountlocalcurrency         True
# 364                             variantpricinginfoprice         True
# 365                 variantpricinginfopriceundiscounted         True
# 366                variantpricinginfopricelocalcurrency         True
# 367                                  taxedmoneycurrency         True
# 368                                     taxedmoneygross         True
# 369                                       taxedmoneynet         True
# 370                                       taxedmoneytax        False
# 371                          selectedattributeattribute         True
# 372                             selectedattributevalues         True
# 373                                      productimageid         True
# 374                               productimagesortorder        False
# 375                                     productimagealt         True
# 376                                     productimageurl         True
# 377                         productvarianttranslationid        False
# 378                       productvarianttranslationname         True
# 379                   productvarianttranslationlanguage         True
# 380                    digitalcontentusedefaultsettings        False
# 381                  digitalcontentautomaticfulfillment         True
# 382                        digitalcontentproductvariant        False
# 383                           digitalcontentcontentfile         True
# 384                          digitalcontentmaxdownloads         True
# 385                          digitalcontenturlvaliddays         True
# 386                                  digitalcontenturls        False
# 387                                    digitalcontentid         True
# 388                       digitalcontentprivatemetadata         True
# 389                              digitalcontentmetadata         True
# 390                            digitalcontenturlcontent        False
# 391                            digitalcontenturlcreated        False
# 392                        digitalcontenturldownloadnum        False
# 393                                 digitalcontenturlid         True
# 394                                digitalcontenturlurl         True
# 395                              digitalcontenturltoken        False
# 396                                      stockwarehouse         True
# 397                                 stockproductvariant         True
# 398                                       stockquantity         True
# 399                                             stockid         True
# 400                              stockquantityallocated         True
# 401                            productpricinginfoonsale         True
# 402                          productpricinginfodiscount         True
# 403             productpricinginfodiscountlocalcurrency        False
# 404                        productpricinginfopricerange         True
# 405            productpricinginfopricerangeundiscounted         True
# 406           productpricinginfopricerangelocalcurrency         True
# 407                                taxedmoneyrangestart         True
# 408                                 taxedmoneyrangestop         True
# 409                                         marginstart         True
# 410                                          marginstop         True
# 411                                  collectionseotitle         True
# 412                            collectionseodescription         True
# 413                                        collectionid         True
# 414                                      collectionname         True
# 415                               collectiondescription         True
# 416                           collectiondescriptionjson         True
# 417                           collectionpublicationdate         True
# 418                                      collectionslug         True
# 419                           collectionprivatemetadata         True
# 420                                  collectionmetadata         True
# 421                                  collectionproducts         True
# 422                           collectionbackgroundimage         True
# 423                               collectiontranslation         True
# 424                               collectionispublished         True
# 425                       collectiontranslationseotitle         True
# 426                 collectiontranslationseodescription         True
# 427                             collectiontranslationid         True
# 428                           collectiontranslationname         True
# 429                    collectiontranslationdescription        False
# 430                collectiontranslationdescriptionjson         True
# 431                       collectiontranslationlanguage         True
# 432               collectiontranslatablecontentseotitle        False
# 433         collectiontranslatablecontentseodescription        False
# 434                     collectiontranslatablecontentid         True
# 435                   collectiontranslatablecontentname         True
# 436            collectiontranslatablecontentdescription        False
# 437        collectiontranslatablecontentdescriptionjson        False
# 438            collectiontranslatablecontenttranslation         True
# 439             collectiontranslatablecontentcollection         True
# 440                 categorytranslatablecontentseotitle        False
# 441           categorytranslatablecontentseodescription        False
# 442                       categorytranslatablecontentid         True
# 443                     categorytranslatablecontentname         True
# 444              categorytranslatablecontentdescription        False
# 445          categorytranslatablecontentdescriptionjson        False
# 446              categorytranslatablecontenttranslation         True
# 447                 categorytranslatablecontentcategory         True
# 448                      attributetranslatablecontentid         True
# 449                    attributetranslatablecontentname         True
# 450             attributetranslatablecontenttranslation         True
# 451               attributetranslatablecontentattribute         True
# 452                 attributevaluetranslatablecontentid         True
# 453               attributevaluetranslatablecontentname         True
# 454        attributevaluetranslatablecontenttranslation         True
# 455     attributevaluetranslatablecontentattributevalue         True
# 456                 productvarianttranslatablecontentid         True
# 457               productvarianttranslatablecontentname         True
# 458        productvarianttranslatablecontenttranslation         True
# 459     productvarianttranslatablecontentproductvariant         True
# 460                     pagetranslatablecontentseotitle        False
# 461               pagetranslatablecontentseodescription        False
# 462                           pagetranslatablecontentid         True
# 463                        pagetranslatablecontenttitle         True
# 464                      pagetranslatablecontentcontent        False
# 465                  pagetranslatablecontentcontentjson        False
# 466                  pagetranslatablecontenttranslation         True
# 467                         pagetranslatablecontentpage         True
# 468                             pagetranslationseotitle        False
# 469                       pagetranslationseodescription        False
# 470                                   pagetranslationid        False
# 471                                pagetranslationtitle         True
# 472                              pagetranslationcontent        False
# 473                          pagetranslationcontentjson        False
# 474                             pagetranslationlanguage         True
# 475                                        pageseotitle        False
# 476                                  pageseodescription        False
# 477                                              pageid         True
# 478                                           pagetitle         True
# 479                                         pagecontent         True
# 480                                     pagecontentjson         True
# 481                                 pagepublicationdate         True
# 482                                            pageslug         True
# 483                                         pagecreated        False
# 484                                 pageprivatemetadata        False
# 485                                        pagemetadata        False
# 486                                     pagetranslation         True
# 487                                     pageispublished         True
# 488                 shippingmethodtranslatablecontentid         True
# 489               shippingmethodtranslatablecontentname         True
# 490        shippingmethodtranslatablecontenttranslation         True
# 491     shippingmethodtranslatablecontentshippingmethod         True
# 492                           saletranslatablecontentid         True
# 493                         saletranslatablecontentname         True
# 494                  saletranslatablecontenttranslation         True
# 495                         saletranslatablecontentsale         True
# 496                                   saletranslationid        False
# 497                                 saletranslationname         True
# 498                             saletranslationlanguage         True
# 499                                              saleid         True
# 500                                            salename         True
# 501                                            saletype         True
# 502                                           salevalue         True
# 503                                       salestartdate         True
# 504                                         saleenddate         True
# 505                                      salecategories        False
# 506                                     salecollections        False
# 507                                        saleproducts        False
# 508                                     saletranslation         True
# 509               collectioncountableconnectionpageinfo         True
# 510                  collectioncountableconnectionedges         True
# 511             collectioncountableconnectiontotalcount        False
# 512                         collectioncountableedgenode         True
# 513                       collectioncountableedgecursor        False
# 514                        vouchertranslatablecontentid         True
# 515                      vouchertranslatablecontentname         True
# 516               vouchertranslatablecontenttranslation         True
# 517                   vouchertranslatablecontentvoucher         True
# 518                                vouchertranslationid        False
# 519                              vouchertranslationname         True
# 520                          vouchertranslationlanguage         True
# 521                                           voucherid         True
# 522                                         vouchername         True
# 523                                         vouchertype         True
# 524                                         vouchercode         True
# 525                                   voucherusagelimit         True
# 526                                         voucherused         True
# 527                                    voucherstartdate         True
# 528                                      voucherenddate         True
# 529                            voucherapplyonceperorder         True
# 530                         voucherapplyoncepercustomer         True
# 531                            voucherdiscountvaluetype         True
# 532                                voucherdiscountvalue         True
# 533                                     voucherminspent         True
# 534                     vouchermincheckoutitemsquantity         True
# 535                                   vouchercategories        False
# 536                                  vouchercollections        False
# 537                                     voucherproducts        False
# 538                                    vouchercountries         True
# 539                                  vouchertranslation         True
# 540                       menuitemtranslatablecontentid         True
# 541                     menuitemtranslatablecontentname         True
# 542              menuitemtranslatablecontenttranslation         True
# 543                 menuitemtranslatablecontentmenuitem         True
# 544                               menuitemtranslationid        False
# 545                             menuitemtranslationname         True
# 546                         menuitemtranslationlanguage         True
# 547                                          menuitemid         True
# 548                                        menuitemname         True
# 549                                        menuitemmenu         True
# 550                                      menuitemparent         True
# 551                                    menuitemcategory         True
# 552                                  menuitemcollection         True
# 553                                        menuitempage         True
# 554                                       menuitemlevel        False
# 555                                    menuitemchildren         True
# 556                                         menuitemurl         True
# 557                                 menuitemtranslation         True
# 558                                              menuid         True
# 559                                            menuname         True
# 560                                            menuslug         True
# 561                                           menuitems         True
# 562                    stockcountableconnectionpageinfo        False
# 563                       stockcountableconnectionedges         True
# 564                  stockcountableconnectiontotalcount         True
# 565                              stockcountableedgenode         True
# 566                            stockcountableedgecursor        False
# 567                        shopavailablepaymentgateways         True
# 568                                 shopgeolocalization         True
# 569                               shopauthorizationkeys         True
# 570                                       shopcountries         True
# 571                                  shopdefaultcountry         True
# 572                           shopdefaultmailsendername         True
# 573                        shopdefaultmailsenderaddress         True
# 574                                     shopdescription         True
# 575                                          shopdomain         True
# 576                                       shoplanguages         True
# 577                                            shopname         True
# 578                                     shoppermissions         True
# 579                                   shopphoneprefixes        False
# 580                                      shopheadertext         True
# 581                            shopincludetaxesinprices         True
# 582                              shopdisplaygrossprices         True
# 583                           shopchargetaxesonshipping         True
# 584                         shoptrackinventorybydefault         True
# 585                               shopdefaultweightunit         True
# 586                                     shoptranslation         True
# 587             shopautomaticfulfillmentdigitalproducts         True
# 588                      shopdefaultdigitalmaxdownloads         True
# 589                      shopdefaultdigitalurlvaliddays         True
# 590                                  shopcompanyaddress         True
# 591                          shopcustomersetpasswordurl         True
# 592                     shopstaffnotificationrecipients         True
# 593                                  paymentgatewayname         True
# 594                                    paymentgatewayid         True
# 595                                paymentgatewayconfig         True
# 596                            paymentgatewaycurrencies         True
# 597                              gatewayconfiglinefield         True
# 598                              gatewayconfiglinevalue         True
# 599                              geolocalizationcountry         True
# 600                                authorizationkeyname         True
# 601                                 authorizationkeykey         True
# 602                                          domainhost         True
# 603                                    domainsslenabled         True
# 604                                           domainurl         True
# 605                                      navigationmain        False
# 606                                 navigationsecondary        False
# 607                                   shoptranslationid        False
# 608                           shoptranslationheadertext         True
# 609                          shoptranslationdescription        False
# 610                             shoptranslationlanguage         True
# 611                      staffnotificationrecipientuser         True
# 612                    staffnotificationrecipientactive         True
# 613                        staffnotificationrecipientid        False
# 614                     staffnotificationrecipientemail         True
# 615                                              userid         True
# 616                                       userlastlogin         True
# 617                                           useremail         True
# 618                                       userfirstname         True
# 619                                        userlastname         True
# 620                                         userisstaff         True
# 621                                        userisactive         True
# 622                                            usernote         True
# 623                                      userdatejoined         True
# 624                          userdefaultshippingaddress         True
# 625                           userdefaultbillingaddress         True
# 626                                 userprivatemetadata         True
# 627                                        usermetadata         True
# 628                                       useraddresses         True
# 629                                        usercheckout         True
# 630                                       usergiftcards         True
# 631                                          userorders         True
# 632                                 useruserpermissions         True
# 633                                userpermissiongroups         True
# 634                                  usereditablegroups         True
# 635                                          useravatar         True
# 636                                          userevents         True
# 637                            userstoredpaymentsources         True
# 638                                     checkoutcreated        False
# 639                                  checkoutlastchange        False
# 640                                        checkoutuser         True
# 641                                    checkoutquantity        False
# 642                              checkoutbillingaddress         True
# 643                             checkoutshippingaddress         True
# 644                              checkoutshippingmethod         True
# 645                                        checkoutnote        False
# 646                                    checkoutdiscount         True
# 647                                checkoutdiscountname         True
# 648                      checkouttranslateddiscountname         True
# 649                                 checkoutvouchercode         True
# 650                                   checkoutgiftcards         True
# 651                                          checkoutid         True
# 652                             checkoutprivatemetadata         True
# 653                                    checkoutmetadata         True
# 654                    checkoutavailableshippingmethods         True
# 655                    checkoutavailablepaymentgateways         True
# 656                                       checkoutemail         True
# 657                          checkoutisshippingrequired         True
# 658                                       checkoutlines         True
# 659                               checkoutshippingprice         True
# 660                               checkoutsubtotalprice         True
# 661                                       checkouttoken         True
# 662                                  checkouttotalprice         True
# 663                                        giftcardcode         True
# 664                                        giftcarduser         True
# ...
# 1529                                   NaN
# 1530                                   NaN
# 1531                                   NaN
# 1532                                   NaN
# 1533                                   NaN
# 1534                                   NaN
# 1535                                   NaN
# 1536                                   NaN
# 1537                                   NaN
# 1538                                   NaN
# 1539                                   NaN
# 1540                                   NaN
# 1541                                   NaN
# 1542                                   NaN
# 1543                                   NaN
# 1544                                   NaN
# 1545                                   NaN
# 1546                                   NaN
# 1547                                   NaN
# 1548                                   NaN
# 1549                                   NaN
# 1550                                   NaN
# 1551                                   NaN
# 1552                                   NaN
# 1553                                   NaN
# 1554                                   NaN
# 1555                                   NaN
# 1556                                   NaN
# 1557                                   NaN
# 1558                                   NaN
# 1559                                   NaN
# 1560                                   NaN
# 1561                                   NaN
# 1562                                   NaN
# 1563                                   NaN
# 1564                                   NaN
# 1565                                   NaN
# 1566                                   NaN
# 1567                                   NaN
# 1568                                   NaN
# 1569                                   NaN
# 1570                                   NaN
# 1571                                   NaN
# 1572                                   NaN
# 1573                                   NaN
# 1574                                   NaN
# 1575                                   NaN
# 1576                                   NaN
# 1577                                   NaN
# 1578                                   NaN
# 1579                                   NaN
# 1580                                   NaN
# 1581                                   NaN
# 1582                                   NaN
# 1583                                   NaN
# 1584                                   NaN
# 1585                                   NaN
# 1586                                   NaN
# 1587                                   NaN
# 1588                                   NaN
# 1589                                   NaN
# 1590                                   NaN
# 1591                                   NaN
# 1592                                   NaN
# 1593                                   NaN
# 1594                                   NaN
# 1595                                   NaN
# 1596                                   NaN
# 1597                                   NaN
# 1598                                   NaN
# 1599                                   NaN
# 1600                                   NaN
# 1601                                   NaN
# 1602                                   NaN
# 1603                                   NaN
# 1604                                   NaN
# 1605                                   NaN
# 1606                                   NaN
# 1607                                   NaN
# 1608                                   NaN
# 1609                                   NaN
# 1610                                   NaN
# 1611                                   NaN
# 1612                                   NaN
# 1613                                   NaN
# 1614                                   NaN
# 1615                                   NaN
# 1616                                   NaN
# 1617                                   NaN
# 1618                                   NaN
# 1619                                   NaN
# 1620                                   NaN
# 1621                                   NaN
# 1622                                   NaN
# 1623                                   NaN
# 1624                                   NaN
# 1625                                   NaN
# 1626                                   NaN
# 1627                                   NaN
# 1628                                   NaN
# 1629                                   NaN
# 1630                                   NaN
# 1631                                   NaN
# 1632                                   NaN
# 1633                                   NaN
# 1634                                   NaN
# 1635                                   NaN
# 1636                                   NaN
# 1637                                   NaN
# 1638                                   NaN
# 1639                                   NaN
# 1640                                   NaN
# 1641                                   NaN
# 1642                                   NaN
# 1643                                   NaN
# 1644                                   NaN
# 1645                                   NaN
# 1646                                   NaN
# 1647                                   NaN
# 1648                                   NaN
# 1649                                   NaN
# 1650                                   NaN
# 1651                                   NaN
# 1652                                   NaN
# 1653                                   NaN
# 1654                                   NaN
# 1655                                   NaN
# 1656                                   NaN
# 1657                                   NaN
# 1658                                   NaN
# 1659                                   NaN
# 1660                                   NaN
# 1661                                   NaN
# 1662                                   NaN
# 1663                                   NaN
# 1664                                   NaN
# 1665                                   NaN
# 1666                                   NaN
# 1667                                   NaN
# 1668                                   NaN
# 1669                                   NaN
# 1670                                   NaN
# 1671                                   NaN
# 1672                                   NaN
# 1673                                   NaN
# 1674                                   NaN
# 1675                                   NaN
# 1676                                   NaN
# 1677                                   NaN
# 1678                                   NaN
# 1679                                   NaN
# 1680                                   NaN
# 1681                                   NaN
# 1682                                   NaN
# 1683                                   NaN
# 1684                                   NaN
# 1685                                   NaN
# 1686                                   NaN
# 1687                                   NaN
# 1688                                   NaN
# 1689                                   NaN
# 1690                                   NaN
# 1691                                   NaN
# 1692                                   NaN
# 1693                                   NaN
# 1694                                   NaN
# 1695                                   NaN
# 1696                                   NaN
# 1697                                   NaN
# 1698                                   NaN
# 1699                                   NaN
# 1700                                   NaN
# 1701                                   NaN
# 1702                                   NaN
# 1703                                   NaN
# 1704                                   NaN
# 1705                                   NaN
# 1706                                   NaN
# 1707                                   NaN
# 1708                                   NaN
# 1709                                   NaN
# 1710                                   NaN
# 1711                                   NaN
# 1712                                   NaN
# 1713                                   NaN
# 1714                                   NaN
# 1715                                   NaN
# 1716                                   NaN
# 1717                                   NaN
# 1718                                   NaN
# 1719                                   NaN
# 1720                                   NaN
# 1721                                   NaN
# 1722                                   NaN
# 1723                                   NaN
# 1724                                   NaN
# 1725                                   NaN
# 1726                                   NaN
# 1727                                   NaN
# 1728                                   NaN
# 1729                                   NaN
# 1730                                   NaN
# 1731                                   NaN
# 1732                                   NaN
# 1733                                   NaN
# 1734                                   NaN
# 1735                                   NaN
# 1736                                   NaN
# 1737                                   NaN
# 1738                                   NaN
# 1739                                   NaN
# 1740                                   NaN
# 1741                                   NaN
# 1742                                   NaN
# 1743                                   NaN
# 1744                                   NaN
# 1745                                   NaN
# 1746                                   NaN
# 1747                                   NaN
# 1748                                   NaN
# 1749                                   NaN
# 1750                                   NaN
# 1751                                   NaN
# 1752                                   NaN
# 1753                                   NaN
# 1754                                   NaN
# 1755                                   NaN
# 1756                                   NaN
# 1757                                   NaN
# 1758                                   NaN
# 1759                                   NaN
# 1760                                   NaN
# 1761                                   NaN
# 1762                                   NaN
# 1763                                   NaN
# 1764                                   NaN
# 1765                                   NaN
# 1766                                   NaN
# 1767                                   NaN
# 1768                                   NaN
# 1769                                   NaN
# 1770                                   NaN
# 1771                                   NaN
# 1772                                   NaN
# 1773                                   NaN
# 1774                                   NaN
# 1775                                   NaN
# 1776                                   NaN
# 1777                                   NaN
# 1778                                   NaN
# 1779                                   NaN
# 1780                                   NaN
# 1781                                   NaN
# 1782                                   NaN
# 1783                                   NaN
# 1784                                   NaN
# 1785                                   NaN
# 1786                                   NaN
# 1787                                   NaN
# 1788                                   NaN
# 1789                                   NaN
# 1790                                   NaN
# 1791                                   NaN
# 1792                                   NaN
# 1793                                   NaN
# 1794                                   NaN
# 1795                                   NaN
# 1796                                   NaN
# 1797                                   NaN
# 1798                                   NaN
# 1799                                   NaN
# 1800                                   NaN
# 1801                                   NaN
# 1802                                   NaN
# 1803                                   NaN
# 1804                                   NaN
# 1805                                   NaN
# 1806                                   NaN
# 1807                                   NaN
# 1808                                   NaN
# 1809                                   NaN
# 1810                                   NaN
# 1811                                   NaN
# 1812                                   NaN
# 1813                                   NaN
# 1814                                   NaN
# 1815                                   NaN
# 1816                                   NaN
# 1817                                   NaN
# 1818                                   NaN
# 1819                                   NaN
# 1820                                   NaN
# 1821                                   NaN
# 1822                                   NaN
# 1823                                   NaN
# 1824                                   NaN
# 1825                                   NaN
# 1826                                   NaN
# 1827                                   NaN
# 1828                                   NaN
# 1829                                   NaN
# 1830                                   NaN
# 1831                                   NaN
# 1832                                   NaN
# 1833                                   NaN
# 1834                                   NaN
# 1835                                   NaN
# 1836                                   NaN
# 1837                                   NaN
# 1838                                   NaN
# 1839                                   NaN
# 1840                                   NaN
# 1841                                   NaN
# 1842                                   NaN
# 1843                                   NaN
# 1844                                   NaN
# 1845                                   NaN
# 1846                                   NaN
# 1847                                   NaN
# 1848                                   NaN
# 1849                                   NaN
# 1850                                   NaN
# 1851                                   NaN
# 1852                                   NaN
# 1853                                   NaN
# 1854                                   NaN
# 1855                                   NaN
# 1856                                   NaN
# 1857                                   NaN
# 1858                                   NaN
# 1859                                   NaN
# 1860                                   NaN
# 1861                                   NaN
# 1862                                   NaN
# 1863                                   NaN
# 1864                                   NaN
# 1865                                   NaN
# 1866                                   NaN
# 1867                                   NaN
# 1868                                   NaN
# 1869                                   NaN
# 1870                                   NaN
# 1871                                   NaN
# 1872                                   NaN
# 1873                                   NaN
# 1874                                   NaN
# 1875                                   NaN
# 1876                                   NaN
# 1877                                   NaN
# 1878                                   NaN
# 1879                                   NaN
# 1880                                   NaN
# 1881                                   NaN
# 1882                                   NaN
# 1883                                   NaN

# %%
merged_df.to_csv('../data/merged-schema-coverage-dictionary.csv')

# %%
schema_sets = (0, 0, 0, 
               (test_coverage.shape[0] - (covered_in_test + only_covered_in_prod.shape[0])), 
               only_covered_in_test.shape[0], 
               only_covered_in_prod.shape[0], covered_by_both.shape[0])

print(schema_sets)

ax = plt.figure(figsize=(8, 8))
schema_venn = venn3(subsets=schema_sets,
                    set_labels = ('Original test suite', 'Generated test suite', 'Total'))

venn3_circles(subsets=schema_sets, linestyle="-", linewidth=2, color='yellow')

for text in schema_venn.set_labels:
    text.set_fontsize(16)
    text.set_text("")
    
for x in range(len(schema_venn.subset_labels)):
    if schema_venn.subset_labels[x] is not None:
        schema_venn.subset_labels[x].set_fontsize(16)
        schema_venn.subset_labels[x].set_fontweight("bold")

h = []
for i in range(len(schema_venn.patches)):
    if schema_venn.patches[i] is not None:
        h.append(schema_venn.patches[i])
        
ax.legend(handles = h, 
          labels=["Not covered by original or generated tests", "Only covered by original tests", "Only covered by generated tests", "Covered by original and generated tests"], 
          bbox_to_anchor=(0.5, 0., 0.6, 0.4),
          fontsize=14,
          framealpha=1,
          edgecolor='black')

plt.savefig('../data/schema-venn.pdf', bbox_inches='tight', pad_inches=0)
# Out:
# (0, 0, 0, 432, 946, 23, 483)

# %%
category_names = ['Tuples']

results = {'¬ (SCHEMA_COV_ORIGINAL ⋃ SCHEMA_COV_GENERATED)': 432,
           'SCHEMA_COV_ORIGINAL − SCHEMA_COV_GENERATED': 946,
           'SCHEMA_COV_ORIGINAL ⋂ SCHEMA_COV_GENERATED': 483,
           '#DISTINCT_TUPLES': 23}

colors=['#f3ea5f', '#77aaff', '#6fcb9f', '#ff6f69']
hatches=['|', '/', 'x', '\\']
df = pd.DataFrame(results, index=category_names)
ax = df.plot.barh(stacked=True, color=colors, figsize=(12, 12), fontsize=20, edgecolor='white', alpha=0.7)

for i, bar in enumerate(ax.patches):
    bar.set_hatch(hatches[i])

for c in ax.containers:
    # format the number of decimal places and replace 0 with an empty string
    labels = [f'{w:.0f}' if (w := v.get_width()) > 0 else '' for v in c ]
    ax.bar_label(c, labels=labels, label_type='center', fontsize=20, color='black', fontweight='bold')
    
ax.legend(fontsize=20, framealpha=1, loc='lower center')

plt.gca().set_axis_off()
plt.subplots_adjust(top = 0.7, bottom = 0, right = 1, left = 0, hspace = 0, wspace = 0)
plt.margins(0, 0)
ax.margins(0, 0)
plt.savefig('../data/schema-venn-rect.pdf', bbox_inches='tight', pad_inches=0)

# %%
schema_sets = (only_covered_in_test.shape[0], only_covered_in_prod.shape[0], covered_by_both.shape[0])

ax = plt.figure(figsize=(8, 8))
schema_venn = venn2(subsets=schema_sets,
                    set_labels = ('Original test suite', 'Generated test suite'),
                    set_colors=('darkcyan', 'hotpink'), alpha = 0.6)


venn2_circles(subsets=schema_sets, linestyle="-", linewidth=2, color='yellow')

for text in schema_venn.set_labels:
    text.set_fontsize(16)
    text.set_text("")
    
for x in range(len(schema_venn.subset_labels)):
    if schema_venn.subset_labels[x] is not None:
        schema_venn.subset_labels[x].set_fontsize(20)
        schema_venn.subset_labels[x].set_fontweight("bold")

h = []
for i in range(len(schema_venn.patches)):
    if schema_venn.patches[i] is not None:
        schema_venn.patches[i].set_edgecolor('yellow')
        h.append(schema_venn.patches[i])

schema_labels = ["SCHEMA_COV_ORIGINAL − SCHEMA_COV_GENERATED", 
                 "SCHEMA_COV_ORIGINAL ⋂ SCHEMA_COV_GENERATED",
                 "#DISTINCT_TUPLES"]
                 
ax.legend(handles = h, 
          labels=["Only covered by original tests", "Only covered by generated tests", "Covered by original and generated tests"], 
          fontsize=18,
          framealpha=0.1,
          edgecolor='black')

plt.savefig('../data/schema-venn2.pdf', bbox_inches='tight', pad_inches=0)
